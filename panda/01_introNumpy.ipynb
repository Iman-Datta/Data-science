# %%
import pandas as pd

s1 = pd.Series([71,89,59,83])
print(s1)
# Out:
# 0    71
# 1    89
# 2    59
# 3    83
# dtype: int64

# %%
import pandas as pd

s2 = pd.Series([71,89,59,83], index=["Iman", "Payel", "Aakash", "Kriti"])
print(s2)
# Out:
# Iman      71
# Payel     89
# Aakash    59
# Kriti     83
# dtype: int64

# %%
import pandas as pd

data = {
    "Name": ["Iman", "Ayesha", "Rahul", "Neha"],
    "Age": [20, 21, 19, 22],
    "Department": ["CSE", "ECE", "CSE", "IT"],
    "Marks": [85, 90, 78, 88]
}

df = pd.DataFrame(data)
print(df)
# Out:
#      Name  Age Department  Marks
# 0    Iman   20        CSE     85
# 1  Ayesha   21        ECE     90
# 2   Rahul   19        CSE     78
# 3    Neha   22         IT     88

# %%
print(df.index)
print(df.columns)
# Out:
# RangeIndex(start=0, stop=4, step=1)
# Index(['Name', 'Age', 'Department', 'Marks'], dtype='object')

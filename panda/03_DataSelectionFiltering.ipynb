# %%
import pandas as pd

df = pd.read_json(r"D:\Data-science\panda\File\actors.json")
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
# ...

# %%
df['Actor'] # Read column
# Out:
# 0         Shah Rukh Khan
# 1            Salman Khan
# 2             Aamir Khan
# 3          Ranbir Kapoor
# 4          Ranveer Singh
# 5     Ayushmann Khurrana
# 6          Rajkummar Rao
# 7         Hrithik Roshan
# 8           Akshay Kumar
# 9          Kartik Aaryan
# 10          Varun Dhawan
# 11         Vicky Kaushal
# Name: Actor, dtype: object

# %%
print(df['Actor'][0])
# Out:
# Shah Rukh Khan

# %%
type(df['Actor'])
# Out:
# pandas.core.series.Series

# %%
df[['Actor', 'IMDb_Rating']]
# Out:
#                  Actor  IMDb_Rating
# 0       Shah Rukh Khan          7.2
# 1          Salman Khan          6.0
# 2           Aamir Khan          8.4
# 3        Ranbir Kapoor          5.6
# 4        Ranveer Singh          7.0
# 5   Ayushmann Khurrana          8.3
# 6        Rajkummar Rao          7.5
# 7       Hrithik Roshan          6.5
# 8         Akshay Kumar          7.0
# 9        Kartik Aaryan          5.9
# 10        Varun Dhawan          6.1
# 11       Vicky Kaushal          8.2

# %%
df.loc[1]    # label-based: Returns the row with index label 1 (label-based selection)
# Out:
# Actor                 Salman Khan
# Film              Tiger Zinda Hai
# Year                         2017
# Genre                      Action
# BoxOffice_IMDb                565
# IMDb_Rating                   6.0
# Name: 1, dtype: object

# %%
df.iloc[1]   # Index-based: Returns the second row based on position (0-based indexing) => By position
# Out:
# Actor                 Salman Khan
# Film              Tiger Zinda Hai
# Year                         2017
# Genre                      Action
# BoxOffice_IMDb                565
# IMDb_Rating                   6.0
# Name: 1, dtype: object

# %%
df.loc[8, 'IMDb_Rating'] # Returns the IMDb_Rating value for the row with index label 8
# Out:
# np.float64(7.0)

# %%
df.iloc[8,5]
# Out:
# np.float64(7.0)

# %%
df.loc[0:2, ["Actor", "IMDb_Rating"]]
# Out:
#             Actor  IMDb_Rating
# 0  Shah Rukh Khan          7.2
# 1     Salman Khan          6.0
# 2      Aamir Khan          8.4

# %%
df.iloc[0:2,0:3]
# Out:
#             Actor             Film  Year
# 0  Shah Rukh Khan          Pathaan  2023
# 1     Salman Khan  Tiger Zinda Hai  2017

# %%
df.at[0, 'Actor']   # Returns the value in the 'Actor' column for the row with index label 0, And it is more optimise, and work on only one element

# there are also has "iat"
# Out:
# 'Shah Rukh Khan'

# %%
df[df['IMDb_Rating']>6] # Filtering
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice_IMDb  IMDb_Rating
# 0             1050          7.2
# 2             2024          8.4
# 4              585          7.0
# 5              111          8.3
# 6              180          7.5
# 7              475          6.5
# ...

# %%
df[df['IMDb_Rating']>6]['Actor'] # Returns the names of actors whose IMDb_Rating is greater than 6
# Out:
# 0         Shah Rukh Khan
# 2             Aamir Khan
# 4          Ranveer Singh
# 5     Ayushmann Khurrana
# 6          Rajkummar Rao
# 7         Hrithik Roshan
# 8           Akshay Kumar
# 10          Varun Dhawan
# 11         Vicky Kaushal
# Name: Actor, dtype: object

# %%
df[(df['IMDb_Rating']>6) & (df['Year']>2018)]
# Out:
#              Actor                      Film  Year   Genre  BoxOffice_IMDb  \
# 0   Shah Rukh Khan                   Pathaan  2023  Action            1050
# 7   Hrithik Roshan                       War  2019  Action             475
# 8     Akshay Kumar                Good Newwz  2019  Comedy             318
# 11   Vicky Kaushal  Uri: The Surgical Strike  2019  Action             342
#
#     IMDb_Rating
# 0           7.2
# 7           6.5
# 8           7.0
# 11          8.2

# %%
df[(df['IMDb_Rating']>6) | (df['Year']>2018)]
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice_IMDb  IMDb_Rating
# 0             1050          7.2
# 2             2024          8.4
# ...

# %%
df.query("Year > 2019 and IMDb_Rating >6") # It gives a copy not view
# Out:
#             Actor     Film  Year   Genre  BoxOffice_IMDb  IMDb_Rating
# 0  Shah Rukh Khan  Pathaan  2023  Action            1050          7.2

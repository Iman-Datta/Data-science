# %%
import pandas as pd

df = pd.read_json(r"D:\Data-science\panda\File\DataCleaning_Preprocessing.json")
df
# Out:
#                name   age        city gender                  email  \
# 0        Iman Datta  20.0     Kolkata      M   iman.datta@gmail.com
# 1       Ayesha Khan  21.0       Delhi      F  ayesha.khan@gmail.com
# 2       Rahul Verma   NaN      Mumbai      M  rahul.verma@gmail.com
# 3       Neha Sharma  23.0        None      F  neha.sharma@gmail.com
# 4       Arjun Singh  25.0  Chandigarh      M                   None
# 5       Priya Mehta  22.0   Ahmedabad      F  priya.mehta@gmail.com
# 6        Sourav Das  24.0     Kolkata      M   sourav.das@gmail.com
# 7        Ritika Sen   NaN        Pune      F   ritika.sen@gmail.com
# 8       Ankit Yadav  26.0       Noida      M  ankit.yadav@gmail.com
# 9         Sneha Roy  21.0     Kolkata      F                   None
# 10      Mohit Gupta  28.0      Jaipur      M  mohit.gupta@gmail.com
# 11       Pooja Nair   NaN       Kochi      F   pooja.nair@gmail.com
# 12   Rohan Malhotra  27.0     Gurgaon      M      rohan.m@gmail.com
# ...

# %%
df.isnull()
# Out:
#      name    age   city  gender  email  joining_date
# 0   False  False  False   False  False         False
# 1   False  False  False   False  False         False
# 2   False   True  False   False  False         False
# 3   False  False   True   False  False         False
# 4   False  False  False   False   True         False
# 5   False  False  False   False  False          True
# 6   False  False  False   False  False         False
# 7   False   True  False   False  False         False
# 8   False  False  False   False  False         False
# 9   False  False  False   False   True         False
# 10  False  False  False   False  False         False
# 11  False   True  False   False  False         False
# 12  False  False  False   False  False          True
# 13  False  False  False   False  False         False
# 14  False  False   True   False  False         False
# 15  False  False  False   False  False         False
# 16  False   True  False   False  False         False
# ...

# %%
df.isnull().sum()
# Out:
# name            0
# age             4
# city            2
# gender          0
# email           3
# joining_date    5
# dtype: int64

# %%
df.dropna()
# Out:
#            name   age     city gender                  email joining_date
# 0    Iman Datta  20.0  Kolkata      M   iman.datta@gmail.com   2023-07-15
# 1   Ayesha Khan  21.0    Delhi      F  ayesha.khan@gmail.com   2022-11-02
# 6    Sourav Das  24.0  Kolkata      M   sourav.das@gmail.com   2023-03-12
# 8   Ankit Yadav  26.0    Noida      M  ankit.yadav@gmail.com   2021-12-05
# 10  Mohit Gupta  28.0   Jaipur      M  mohit.gupta@gmail.com   2018-04-19
# 13   Kavya Iyer  24.0  Chennai      F   kavya.iyer@gmail.com   2022-02-14
# 15  Nisha Patel  23.0    Surat      F  nisha.patel@gmail.com   2021-09-21
# 19  Riya Kapoor  20.0    Delhi      F  riya.kapoor@gmail.com   2024-01-10
# 20  Ayesha Khan  21.0    Delhi      F  ayesha.khan@gmail.com   2022-11-02

# %%
df.dropna(axis=1)
# Out:
#                name gender
# 0        Iman Datta      M
# 1       Ayesha Khan      F
# 2       Rahul Verma      M
# 3       Neha Sharma      F
# 4       Arjun Singh      M
# 5       Priya Mehta      F
# 6        Sourav Das      M
# 7        Ritika Sen      F
# 8       Ankit Yadav      M
# 9         Sneha Roy      F
# 10      Mohit Gupta      M
# 11       Pooja Nair      F
# 12   Rohan Malhotra      M
# 13       Kavya Iyer      F
# 14  Aditya Kulkarni      M
# 15      Nisha Patel      F
# 16   Aman Choudhary      M
# 17       Tanya Bose      F
# 18    Deepak Mishra      M
# 19      Riya Kapoor      F
# 20      Ayesha Khan      F
# 21       Tanya Bose      F
# 22   Rohan Malhotra      M

# %%
df.fillna(0)
# Out:
#                name   age        city gender                  email  \
# 0        Iman Datta  20.0     Kolkata      M   iman.datta@gmail.com
# 1       Ayesha Khan  21.0       Delhi      F  ayesha.khan@gmail.com
# 2       Rahul Verma   0.0      Mumbai      M  rahul.verma@gmail.com
# 3       Neha Sharma  23.0           0      F  neha.sharma@gmail.com
# 4       Arjun Singh  25.0  Chandigarh      M                      0
# 5       Priya Mehta  22.0   Ahmedabad      F  priya.mehta@gmail.com
# 6        Sourav Das  24.0     Kolkata      M   sourav.das@gmail.com
# 7        Ritika Sen   0.0        Pune      F   ritika.sen@gmail.com
# 8       Ankit Yadav  26.0       Noida      M  ankit.yadav@gmail.com
# 9         Sneha Roy  21.0     Kolkata      F                      0
# 10      Mohit Gupta  28.0      Jaipur      M  mohit.gupta@gmail.com
# 11       Pooja Nair   0.0       Kochi      F   pooja.nair@gmail.com
# 12   Rohan Malhotra  27.0     Gurgaon      M      rohan.m@gmail.com
# ...

# %%
# df["age"].fillna(df["age"].mean())

# %%
df.fillna(method="ffill") # forward fill
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_27400\2535960854.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method="ffill") # forward fill
#                name   age        city gender                  email  \
# 0        Iman Datta  20.0     Kolkata      M   iman.datta@gmail.com
# 1       Ayesha Khan  21.0       Delhi      F  ayesha.khan@gmail.com
# 2       Rahul Verma  21.0      Mumbai      M  rahul.verma@gmail.com
# 3       Neha Sharma  23.0      Mumbai      F  neha.sharma@gmail.com
# 4       Arjun Singh  25.0  Chandigarh      M  neha.sharma@gmail.com
# 5       Priya Mehta  22.0   Ahmedabad      F  priya.mehta@gmail.com
# 6        Sourav Das  24.0     Kolkata      M   sourav.das@gmail.com
# 7        Ritika Sen  24.0        Pune      F   ritika.sen@gmail.com
# 8       Ankit Yadav  26.0       Noida      M  ankit.yadav@gmail.com
# ...

# %%
df.bfill() # backward fill
# Out:
#                name   age        city gender                  email  \
# 0        Iman Datta  20.0     Kolkata      M   iman.datta@gmail.com
# 1       Ayesha Khan  21.0       Delhi      F  ayesha.khan@gmail.com
# 2       Rahul Verma  23.0      Mumbai      M  rahul.verma@gmail.com
# 3       Neha Sharma  23.0  Chandigarh      F  neha.sharma@gmail.com
# 4       Arjun Singh  25.0  Chandigarh      M  priya.mehta@gmail.com
# 5       Priya Mehta  22.0   Ahmedabad      F  priya.mehta@gmail.com
# 6        Sourav Das  24.0     Kolkata      M   sourav.das@gmail.com
# 7        Ritika Sen  26.0        Pune      F   ritika.sen@gmail.com
# 8       Ankit Yadav  26.0       Noida      M  ankit.yadav@gmail.com
# 9         Sneha Roy  21.0     Kolkata      F  mohit.gupta@gmail.com
# 10      Mohit Gupta  28.0      Jaipur      M  mohit.gupta@gmail.com
# 11       Pooja Nair  27.0       Kochi      F   pooja.nair@gmail.com
# 12   Rohan Malhotra  27.0     Gurgaon      M      rohan.m@gmail.com
# ...

# %%
df.duplicated(["email"])
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19    False
# 20     True
# 21     True
# 22     True
# dtype: bool

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20     True
# 21     True
# 22     True
# dtype: bool

# %%
df.drop_duplicates() # It removes duplicate data
# Out:
#                name   age        city gender                  email  \
# 0        Iman Datta  20.0     Kolkata      M   iman.datta@gmail.com
# 1       Ayesha Khan  21.0       Delhi      F  ayesha.khan@gmail.com
# 2       Rahul Verma   NaN      Mumbai      M  rahul.verma@gmail.com
# 3       Neha Sharma  23.0        None      F  neha.sharma@gmail.com
# 4       Arjun Singh  25.0  Chandigarh      M                   None
# 5       Priya Mehta  22.0   Ahmedabad      F  priya.mehta@gmail.com
# 6        Sourav Das  24.0     Kolkata      M   sourav.das@gmail.com
# 7        Ritika Sen   NaN        Pune      F   ritika.sen@gmail.com
# 8       Ankit Yadav  26.0       Noida      M  ankit.yadav@gmail.com
# 9         Sneha Roy  21.0     Kolkata      F                   None
# 10      Mohit Gupta  28.0      Jaipur      M  mohit.gupta@gmail.com
# 11       Pooja Nair   NaN       Kochi      F   pooja.nair@gmail.com
# 12   Rohan Malhotra  27.0     Gurgaon      M      rohan.m@gmail.com
# ...

# %%
df["name"].str.lower()
# Out:
# 0          iman datta
# 1         ayesha khan
# 2         rahul verma
# 3         neha sharma
# 4         arjun singh
# 5         priya mehta
# 6          sourav das
# 7          ritika sen
# 8         ankit yadav
# 9           sneha roy
# 10        mohit gupta
# 11         pooja nair
# 12     rohan malhotra
# 13         kavya iyer
# 14    aditya kulkarni
# 15        nisha patel
# 16     aman choudhary
# 17         tanya bose
# 18      deepak mishra
# 19        riya kapoor
# 20        ayesha khan
# 21         tanya bose
# 22     rohan malhotra
# Name: name, dtype: object

# %%
df["city"].str.contains("delhi", case=False) # Checks if "delhi" is the in the city name, case insensitive.
# Out:
# 0     False
# 1      True
# 2     False
# 3      None
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14     None
# 15    False
# 16    False
# 17    False
# 18    False
# 19     True
# 20     True
# 21    False
# 22    False
# Name: city, dtype: object

# %%
df["email"].str.split('@')
# Out:
# 0      [iman.datta, gmail.com]
# 1     [ayesha.khan, gmail.com]
# 2     [rahul.verma, gmail.com]
# 3     [neha.sharma, gmail.com]
# 4                         None
# 5     [priya.mehta, gmail.com]
# 6      [sourav.das, gmail.com]
# 7      [ritika.sen, gmail.com]
# 8     [ankit.yadav, gmail.com]
# 9                         None
# 10    [mohit.gupta, gmail.com]
# 11     [pooja.nair, gmail.com]
# 12        [rohan.m, gmail.com]
# 13     [kavya.iyer, gmail.com]
# 14       [aditya.k, gmail.com]
# 15    [nisha.patel, gmail.com]
# 16         [aman.c, gmail.com]
# 17     [tanya.bose, gmail.com]
# 18                        None
# 19    [riya.kapoor, gmail.com]
# 20    [ayesha.khan, gmail.com]
# 21     [tanya.bose, gmail.com]
# 22        [rohan.m, gmail.com]
# Name: email, dtype: object

# %%
df2 = df.dropna().copy()

# %%
df2["age"] = df2["age"].astype(int)
df2
# Out:
#            name  age     city gender                  email joining_date
# 0    Iman Datta   20  Kolkata      M   iman.datta@gmail.com   2023-07-15
# 1   Ayesha Khan   21    Delhi      F  ayesha.khan@gmail.com   2022-11-02
# 6    Sourav Das   24  Kolkata      M   sourav.das@gmail.com   2023-03-12
# 8   Ankit Yadav   26    Noida      M  ankit.yadav@gmail.com   2021-12-05
# 10  Mohit Gupta   28   Jaipur      M  mohit.gupta@gmail.com   2018-04-19
# 13   Kavya Iyer   24  Chennai      F   kavya.iyer@gmail.com   2022-02-14
# 15  Nisha Patel   23    Surat      F  nisha.patel@gmail.com   2021-09-21
# 19  Riya Kapoor   20    Delhi      F  riya.kapoor@gmail.com   2024-01-10
# 20  Ayesha Khan   21    Delhi      F  ayesha.khan@gmail.com   2022-11-02

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, 0 to 20
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          9 non-null      object
#  1   age           9 non-null      int64
#  2   city          9 non-null      object
#  3   gender        9 non-null      object
#  4   email         9 non-null      object
#  5   joining_date  9 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 504.0+ bytes

# %%
df2["age group"] = df2["age"].apply(lambda x: "Adult" if x >=18 else "Minor")
df2
# Out:
#            name  age     city gender                  email joining_date  \
# 0    Iman Datta   20  Kolkata      M   iman.datta@gmail.com   2023-07-15
# 1   Ayesha Khan   21    Delhi      F  ayesha.khan@gmail.com   2022-11-02
# 6    Sourav Das   24  Kolkata      M   sourav.das@gmail.com   2023-03-12
# 8   Ankit Yadav   26    Noida      M  ankit.yadav@gmail.com   2021-12-05
# 10  Mohit Gupta   28   Jaipur      M  mohit.gupta@gmail.com   2018-04-19
# 13   Kavya Iyer   24  Chennai      F   kavya.iyer@gmail.com   2022-02-14
# 15  Nisha Patel   23    Surat      F  nisha.patel@gmail.com   2021-09-21
# 19  Riya Kapoor   20    Delhi      F  riya.kapoor@gmail.com   2024-01-10
# 20  Ayesha Khan   21    Delhi      F  ayesha.khan@gmail.com   2022-11-02
#
#    age group
# 0      Adult
# 1      Adult
# 6      Adult
# 8      Adult
# 10     Adult
# 13     Adult
# 15     Adult
# 19     Adult
# 20     Adult

# %%
def isMinor(x):
    return "Adult" if x >= 18 else "Minor"
df2["age group"] = df2["age"].apply(isMinor)
df2
# Out:
#            name  age     city gender                  email joining_date  \
# 0    Iman Datta   20  Kolkata      M   iman.datta@gmail.com   2023-07-15
# 1   Ayesha Khan   21    Delhi      F  ayesha.khan@gmail.com   2022-11-02
# 6    Sourav Das   24  Kolkata      M   sourav.das@gmail.com   2023-03-12
# 8   Ankit Yadav   26    Noida      M  ankit.yadav@gmail.com   2021-12-05
# 10  Mohit Gupta   28   Jaipur      M  mohit.gupta@gmail.com   2018-04-19
# 13   Kavya Iyer   24  Chennai      F   kavya.iyer@gmail.com   2022-02-14
# 15  Nisha Patel   23    Surat      F  nisha.patel@gmail.com   2021-09-21
# 19  Riya Kapoor   20    Delhi      F  riya.kapoor@gmail.com   2024-01-10
# 20  Ayesha Khan   21    Delhi      F  ayesha.khan@gmail.com   2022-11-02
#
#    age group
# 0      Adult
# 1      Adult
# 6      Adult
# 8      Adult
# 10     Adult
# 13     Adult
# 15     Adult
# 19     Adult
# 20     Adult

# %%
gender_map = {"M" : "Male", "F" : "Female", "O" : "Other"}
df2["gender"] = df2["gender"].map(gender_map)
df2
# Out:
#            name  age     city  gender                  email joining_date  \
# 0    Iman Datta   20  Kolkata    Male   iman.datta@gmail.com   2023-07-15
# 1   Ayesha Khan   21    Delhi  Female  ayesha.khan@gmail.com   2022-11-02
# 6    Sourav Das   24  Kolkata    Male   sourav.das@gmail.com   2023-03-12
# 8   Ankit Yadav   26    Noida    Male  ankit.yadav@gmail.com   2021-12-05
# 10  Mohit Gupta   28   Jaipur    Male  mohit.gupta@gmail.com   2018-04-19
# 13   Kavya Iyer   24  Chennai  Female   kavya.iyer@gmail.com   2022-02-14
# 15  Nisha Patel   23    Surat  Female  nisha.patel@gmail.com   2021-09-21
# 19  Riya Kapoor   20    Delhi  Female  riya.kapoor@gmail.com   2024-01-10
# 20  Ayesha Khan   21    Delhi  Female  ayesha.khan@gmail.com   2022-11-02
#
#    age group
# 0      Adult
# 1      Adult
# 6      Adult
# 8      Adult
# 10     Adult
# 13     Adult
# 15     Adult
# 19     Adult
# 20     Adult
